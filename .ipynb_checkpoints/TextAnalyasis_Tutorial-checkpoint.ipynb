# %%
cd("/home/jzhang/gis_data/jzhang/MyAI")
using Pkg; 
import Pkg; 
Pkg.activate(".")
# Out:
#   Activating project at `~/MyAI`

# %%
Pkg.add("TextAnalysis")
# Out:
#    Resolving package versions...
#   No Changes to `~/MyAI/Project.toml`
#   No Changes to `~/MyAI/Manifest.toml`

# %%
using TextAnalysis

# %%
str = "To be or not to be ..."
# Out:
# "To be or not to be ..."

# %%
sd = StringDocument(str)
# Out:
# A StringDocument{String}
#  * Language: Languages.English()
#  * Title: Untitled Document
#  * Author: Unknown Author
#  * Timestamp: Unknown Time
#  * Snippet: To be or not to be ...

# %%
td = TokenDocument("To be or not to be")
# Out:
# A TokenDocument{String}
#  * Language: Languages.English()
#  * Title: Untitled Document
#  * Author: Unknown Author
#  * Timestamp: Unknown Time
#  * Snippet: ***SAMPLE TEXT NOT AVAILABLE***

# %%
ngd = NGramDocument("To be or not to be")
# Out:
# A NGramDocument{String}
#  * Language: Languages.English()
#  * Title: Untitled Document
#  * Author: Unknown Author
#  * Timestamp: Unknown Time
#  * Snippet: ***SAMPLE TEXT NOT AVAILABLE***

# %%
tokens(sd)
# Out:
# 6-element Vector{String}:
#  "To"
#  "be"
#  "or"
#  "not"
#  "to"
#  "be"

# %%
ngrams(sd)
# Out:
# Dict{String, Int64} with 5 entries:
#   "or"  => 1
#   "not" => 1
#   "to"  => 1
#   "To"  => 1
#   "be"  => 2

# %%
#Pkg.add("GLM");
Pkg.add("CSV");
Pkg.add("PrettyPrinting");
# Out:
#    Resolving package versions...
#   No Changes to `~/MyAI/Project.toml`
#   No Changes to `~/MyAI/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/MyAI/Project.toml`
#   No Changes to `~/MyAI/Manifest.toml`

# %%
using DataFrames;
using GLM;
using CSV;
using Gadfly;
using TextAnalysis;
using MLJ;
using Chain;
using Pipe;
using StableRNGs;

df = CSV.read("titanic-dataset.csv", DataFrame, header=true);
first(df, 10) |> pretty
# Out:
# ┌─────────────┬──────────┬────────┬─────────────────────────────────────────────────────┬─────────┬────────────────────────────┬───────┬───────┬──────────────────┬────────────┬──────────────────────────┬─────────────────────────┐
# │ PassengerId │ Survived │ Pclass │ Name                                                │ Sex     │ Age                        │ SibSp │ Parch │ Ticket           │ Fare       │ Cabin                    │ Embarked                │
# │ Int64       │ Int64    │ Int64  │ String                                              │ String7 │ Union{Missing, Float64}    │ Int64 │ Int64 │ String31         │ Float64    │ Union{Missing, String15} │ Union{Missing, String1} │
# │ Count       │ Count    │ Count  │ Textual                                             │ Textual │ Union{Missing, Continuous} │ Count │ Count │ Textual          │ Continuous │ Union{Missing, Textual}  │ Union{Missing, Textual} │
# ├─────────────┼──────────┼────────┼─────────────────────────────────────────────────────┼─────────┼────────────────────────────┼───────┼───────┼──────────────────┼────────────┼──────────────────────────┼─────────────────────────┤
# │ 1           │ 0        │ 3      │ Braund, Mr. Owen Harris                             │ male    │ 22.0                       │ 1     │ 0     │ A/5 21171        │ 7.25       │ missing                  │ S                       │
# │ 2           │ 1        │ 1      │ Cumings, Mrs. John Bradley (Florence Briggs Thayer) │ female  │ 38.0                       │ 1     │ 0     │ PC 17599         │ 71.2833    │ C85                      │ C                       │
# │ 3           │ 1        │ 3      │ Heikkinen, Miss. Laina                              │ female  │ 26.0                       │ 0     │ 0     │ STON/O2. 3101282 │ 7.925      │ missing                  │ S                       │
# │ 4           │ 1        │ 1      │ Futrelle, Mrs. Jacques Heath (Lily May Peel)        │ female  │ 35.0                       │ 1     │ 0     │ 113803           │ 53.1       │ C123                     │ S                       │
# │ 5           │ 0        │ 3      │ Allen, Mr. William Henry                            │ male    │ 35.0                       │ 0     │ 0     │ 373450           │ 8.05       │ missing                  │ S                       │
# │ 6           │ 0        │ 3      │ Moran, Mr. James                                    │ male    │ missing                    │ 0     │ 0     │ 330877           │ 8.4583     │ missing                  │ Q                       │
# │ 7           │ 0        │ 1      │ McCarthy, Mr. Timothy J                             │ male    │ 54.0                       │ 0     │ 0     │ 17463            │ 51.8625    │ E46                      │ S                       │
# │ 8           │ 0        │ 3      │ Palsson, Master. Gosta Leonard                      │ male    │ 2.0                        │ 3     │ 1     │ 349909           │ 21.075     │ missing                  │ S                       │
# │ 9           │ 1        │ 3      │ Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   │ female  │ 27.0                       │ 0     │ 2     │ 347742           │ 11.1333    │ missing                  │ S                       │
# │ 10          │ 1        │ 2      │ Nasser, Mrs. Nicholas (Adele Achem)                 │ female  │ 14.0                       │ 1     │ 0     │ 237736           │ 30.0708    │ missing                  │ C                       │
# └─────────────┴──────────┴────────┴─────────────────────────────────────────────────────┴─────────┴────────────────────────────┴───────┴───────┴──────────────────┴────────────┴──────────────────────────┴─────────────────────────┘

# %%
delete!(df, :PassengerId);
delete!(df, :Name);
delete!(df, :Ticket);
delete!(df, :Cabin);
df[isna.(df[:Age]),:Age] = median(df[ .~isna.(df[:Age]),:Age])
df[isna.(df[:Embarked]),:Embarked] = "S"
pool!(df, [:Sex]);
pool!(df, [:Embarked]);
# Out:
# MethodError: no method matching deleteat!(::DataFrame, ::Symbol)
# The function `deleteat!` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   deleteat!(::SentinelArrays.MissingVector, ::Any)
#    @ SentinelArrays ~/.julia/packages/SentinelArrays/vt8A6/src/missingvector.jl:57
#   deleteat!(::DataFrame, ::Colon)
#    @ DataFrames ~/.julia/packages/DataFrames/kcA9R/src/dataframe/dataframe.jl:856
#   deleteat!(::DataFrame, ::Integer)
#    @ DataFrames ~/.julia/packages/DataFrames/kcA9R/src/dataframe/dataframe.jl:858
#   ...
#
#
# Stacktrace:
#  [1] delete!(df::DataFrame, inds::Symbol)
#    @ DataFrames ./deprecated.jl:105
#  [2] top-level scope
#    @ In[38]:1

# %%
split_pt = trunc(Int,size(df,1)*0.7) # 70% validation
shuffle_idx = sample(1:size(df,1),size(df,1));
df_train = df[1:split_pt,:];
df_validate = df[split_pt+1:size(df,1),:];

# %%
model = glm(@formula(Survived ~ Pclass + Sex + Age + SibSp + Parch + Fare + Embarked), df_train, Binomial(), LogitLink());
pred = predict(model,df_validate);
pred = convert(DataArray{Int}, round.(pred));

# %%
print("Accuracy: ")
println( sum(pred .== df_validate[:Survived]) / length(pred))
