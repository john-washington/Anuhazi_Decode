# %% [markdown]
# https://juliaai.github.io/MLJ.jl/stable/getting_started/

# %%
cd("/home/jzhang/gis_data/jzhang/MyAI")
using Pkg; 
import Pkg; 
Pkg.activate(".")
# Out:
#   Activating project at `/media/jzhang/gis_data/jzhang/MyAI`

# %%
Pkg.add("MLJ")
# Out:
#    Resolving package versions...
# Unsatisfiable requirements detected for package PrimitiveOneHot [13d12f88]:
#  PrimitiveOneHot [13d12f88] log:
#  ├─possible versions are: 0.1.0 - 0.2.1 or uninstalled
#  ├─required (without additional version restrictions) by Transformers [21ca0261]
#  │ └─Transformers [21ca0261] log:
#  │   ├─possible versions are: 0.0.1 - 0.3.1 or uninstalled
#  │   ├─restricted to versions * by project [03412277], leaving only versions: 0.0.1 - 0.3.1
#  │   │ └─project [03412277] log:
#  │   │   ├─possible versions are: 0.0.0 or uninstalled
#  │   │   └─project [03412277] is fixed to version 0.0.0
#  │   ├─restricted by compatibility requirements with CUDAnative [be33ccc6] to versions: [0.0.6 - 0.1.1, 0.1.4 - 0.3.1] or uninstalled, leaving only versions: [0.0.6 - 0.1.1, 0.1.4 - 0.3.1]
#  │   │ └─CUDAnative [be33ccc6] log:
#  │   │   ├─possible versions are: 0.7.0 - 3.2.0 or uninstalled
# ...

# %%
using MLJ
iris = load_iris();
selectrows(iris, 1:3) |> pretty
# Out:
# [ Info: Precompiling MLJ [add582a8-e3ab-11e8-2d5e-e98b27df1bc7]
# [ Info: Precompiling MLJ [add582a8-e3ab-11e8-2d5e-e98b27df1bc7]
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# ...

# %%
schema(iris)
# Out:
# UndefVarError: `schema` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[8]:1
#  [2] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %%
import DataFrames
iris = DataFrames.DataFrame(iris);

# %%
y, X = unpack(iris, ==(:target); rng=123);

# %%
first(X, 3) |> pretty
# Out:
# ┌──────────────┬─────────────┬──────────────┬─────────────┐
# │ sepal_length │ sepal_width │ petal_length │ petal_width │
# │ Float64      │ Float64     │ Float64      │ Float64     │
# │ Continuous   │ Continuous  │ Continuous   │ Continuous  │
# ├──────────────┼─────────────┼──────────────┼─────────────┤
# │ 6.5          │ 2.8         │ 4.6          │ 1.5         │
# │ 5.1          │ 3.5         │ 1.4          │ 0.2         │
# │ 6.3          │ 3.3         │ 4.7          │ 1.6         │
# └──────────────┴─────────────┴──────────────┴─────────────┘

# %%
models(matching(X, y))
# Out:
# 54-element Vector{NamedTuple{(:name, :package_name, :is_supervised, :abstract_type, :constructor, :deep_properties, :docstring, :fit_data_scitype, :human_name, :hyperparameter_ranges, :hyperparameter_types, :hyperparameters, :implemented_methods, :inverse_transform_scitype, :is_pure_julia, :is_wrapper, :iteration_parameter, :load_path, :package_license, :package_url, :package_uuid, :predict_scitype, :prediction_type, :reporting_operations, :reports_feature_importances, :supports_class_weights, :supports_online, :supports_training_losses, :supports_weights, :target_in_fit, :transform_scitype, :input_scitype, :target_scitype, :output_scitype)}}:
#  (name = AdaBoostClassifier, package_name = MLJScikitLearnInterface, ... )
#  (name = AdaBoostStumpClassifier, package_name = DecisionTree, ... )
#  (name = BaggingClassifier, package_name = MLJScikitLearnInterface, ... )
#  (name = BayesianLDA, package_name = MLJScikitLearnInterface, ... )
# ...

# %%
info("PCA")
# Out:
# (name = "PCA",
#  package_name = "MultivariateStats",
#  is_supervised = false,
#  abstract_type = Unsupervised,
#  constructor = nothing,
#  deep_properties = (),
#  docstring = "```\nPCA\n```\n\nA model type for constructing a pca, ...",
#  fit_data_scitype = Tuple{Table{<:AbstractVector{<:Continuous}}},
#  human_name = "pca",
#  hyperparameter_ranges = (nothing, nothing, nothing, nothing),
#  hyperparameter_types =
#      ("Int64", "Symbol", "Float64", "Union{Nothing, Real, Vector{Float64}}"),
#  hyperparameters = (:maxoutdim, :method, :variance_ratio, :mean),
#  implemented_methods =
#      [:clean!, :fit, :fitted_params, :inverse_transform, :transform],
#  inverse_transform_scitype = Table{<:AbstractVector{<:Continuous}},
#  is_pure_julia = true,
#  is_wrapper = false,
#  iteration_parameter = nothing,
#  load_path = "MLJMultivariateStatsInterface.PCA",
#  package_license = "MIT",
#  package_url = "https://github.com/JuliaStats/MultivariateStats.jl",
# ...

# %%
localmodels()
# Out:
# 15-element Vector{NamedTuple{(:name, :package_name, :is_supervised, :abstract_type, :constructor, :deep_properties, :docstring, :fit_data_scitype, :human_name, :hyperparameter_ranges, :hyperparameter_types, :hyperparameters, :implemented_methods, :inverse_transform_scitype, :is_pure_julia, :is_wrapper, :iteration_parameter, :load_path, :package_license, :package_url, :package_uuid, :predict_scitype, :prediction_type, :reporting_operations, :reports_feature_importances, :supports_class_weights, :supports_online, :supports_training_losses, :supports_weights, :target_in_fit, :transform_scitype, :input_scitype, :target_scitype, :output_scitype)}}:
#  (name = ConstantClassifier, package_name = MLJModels, ... )
#  (name = ConstantRegressor, package_name = MLJModels, ... )
#  (name = ContinuousEncoder, package_name = MLJModels, ... )
#  (name = DeterministicConstantClassifier, package_name = MLJModels, ... )
#  (name = DeterministicConstantRegressor, package_name = MLJModels, ... )
# ...
